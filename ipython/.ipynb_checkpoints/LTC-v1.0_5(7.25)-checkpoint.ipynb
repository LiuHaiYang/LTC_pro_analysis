# %%
# %matplotlib inline
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymongo

# %%
client = pymongo.MongoClient('172.16.100.54',27017)
ltc_data= client['ltc_collect']

# %%
result = pd.read_csv('ltc_v1.0_Data_7_25_5.csv',sep=',')
result.head()
# result.dtypes
# Out:
#    id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt   BW   CR  \
# 0   1                    39  LTC-base1    1    2    2    8      -86  125  4/5
# 1   2                    39  LTC-base1    1    2    4    8      -84  125  4/5
# 2   3                    39  LTC-base1    1    2    7    8      -90  125  4/5
# 3   4                    39  LTC-base1    1    2    0    8      -91  125  4/5
# 4   5                    39  LTC-base1    1    2    1    7      -88  125  4/5
#
#    SF  sensor_id  version  command_id  data_length data  mote_lon  mote_lat  \
# 0  12          2        1           9            1    ,       0.0       0.0
# 1  12          2        1           9            1    ,       0.0       0.0
# 2  12          2        1           9            1    ,       0.0       0.0
# 3  12          2        1           9            1    ,       0.0       0.0
# 4  12          2        1           9            1    ,       0.0       0.0
#
#              time  distance2base
# ...

# %%
result.count()
# Out:
# id                      418
# collcetion_latest_id    418
# base_topic              418
# dst                     418
# src                     418
# seq                     418
# SNR                     418
# RSSIpkt                 418
# BW                      418
# CR                      418
# SF                      418
# sensor_id               418
# version                 418
# command_id              418
# data_length             418
# data                    418
# mote_lon                418
# mote_lat                418
# time                    418
# distance2base           418
# dtype: int64

# %%
mote_2 = result[result['src']==2]
mote_2.count()
# Out:
# id                      112
# collcetion_latest_id    112
# base_topic              112
# dst                     112
# src                     112
# seq                     112
# SNR                     112
# RSSIpkt                 112
# BW                      112
# CR                      112
# SF                      112
# sensor_id               112
# version                 112
# command_id              112
# data_length             112
# data                    112
# mote_lon                112
# mote_lat                112
# time                    112
# distance2base           112
# dtype: int64

# %%
mote_3 = result[result['src']==3]
mote_3.count()
# Out:
# id                      141
# collcetion_latest_id    141
# base_topic              141
# dst                     141
# src                     141
# seq                     141
# SNR                     141
# RSSIpkt                 141
# BW                      141
# CR                      141
# SF                      141
# sensor_id               141
# version                 141
# command_id              141
# data_length             141
# data                    141
# mote_lon                141
# mote_lat                141
# time                    141
# distance2base           141
# dtype: int64

# %%
mote_4 = result[result['src']==4]
mote_4.count()
# Out:
# id                      165
# collcetion_latest_id    165
# base_topic              165
# dst                     165
# src                     165
# seq                     165
# SNR                     165
# RSSIpkt                 165
# BW                      165
# CR                      165
# SF                      165
# sensor_id               165
# version                 165
# command_id              165
# data_length             165
# data                    165
# mote_lon                165
# mote_lat                165
# time                    165
# distance2base           165
# dtype: int64

# %%
result.count()
# Out:
# id                      418
# collcetion_latest_id    418
# base_topic              418
# dst                     418
# src                     418
# seq                     418
# SNR                     418
# RSSIpkt                 418
# BW                      418
# CR                      418
# SF                      418
# sensor_id               418
# version                 418
# command_id              418
# data_length             418
# data                    418
# mote_lon                418
# mote_lat                418
# time                    418
# distance2base           418
# dtype: int64

# %%
result
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt   BW  \
# 0      1                    39  LTC-base1    1    2    2    8      -86  125
# 1      2                    39  LTC-base1    1    2    4    8      -84  125
# 2      3                    39  LTC-base1    1    2    7    8      -90  125
# 3      4                    39  LTC-base1    1    2    0    8      -91  125
# 4      5                    39  LTC-base1    1    2    1    7      -88  125
# 5      6                    39  LTC-base1    1    2    2    8      -88  125
# 6      7                    39  LTC-base1    1    2    3    8      -86  125
# 7      8                    39  LTC-base1    1    2    4    7      -91  125
# 8      9                    39  LTC-base1    1    2    6    8      -83  125
# 9     10                    39  LTC-base1    1    2    8    8      -87  125
# 10    11                    39  LTC-base1    1    2    9    7      -96  125
# ...

# %%
address1=result[result['id']<69]
address1.count()
# Out:
# id                      68
# collcetion_latest_id    68
# base_topic              68
# dst                     68
# src                     68
# seq                     68
# SNR                     68
# RSSIpkt                 68
# BW                      68
# CR                      68
# SF                      68
# sensor_id               68
# version                 68
# command_id              68
# data_length             68
# data                    68
# mote_lon                68
# mote_lat                68
# time                    68
# distance2base           68
# dtype: int64

# %%
address2_1=result[result['id']>68]
address2=address2_1[address2_1['id']<135]
address2.count()
# Out:
# id                      66
# collcetion_latest_id    66
# base_topic              66
# dst                     66
# src                     66
# seq                     66
# SNR                     66
# RSSIpkt                 66
# BW                      66
# CR                      66
# SF                      66
# sensor_id               66
# version                 66
# command_id              66
# data_length             66
# data                    66
# mote_lon                66
# mote_lat                66
# time                    66
# distance2base           66
# dtype: int64

# %%
address3_1=result[result['id']>134]
address3=address3_1[address3_1['id']<204]
address3.count()
# Out:
# id                      69
# collcetion_latest_id    69
# base_topic              69
# dst                     69
# src                     69
# seq                     69
# SNR                     69
# RSSIpkt                 69
# BW                      69
# CR                      69
# SF                      69
# sensor_id               69
# version                 69
# command_id              69
# data_length             69
# data                    69
# mote_lon                69
# mote_lat                69
# time                    69
# distance2base           69
# dtype: int64

# %%
address4_1=result[result['id']>203]
address4=address4_1[address4_1['id']<276]
address4.count()
# Out:
# id                      72
# collcetion_latest_id    72
# base_topic              72
# dst                     72
# src                     72
# seq                     72
# SNR                     72
# RSSIpkt                 72
# BW                      72
# CR                      72
# SF                      72
# sensor_id               72
# version                 72
# command_id              72
# data_length             72
# data                    72
# mote_lon                72
# mote_lat                72
# time                    72
# distance2base           72
# dtype: int64

# %%
address5_1=result[result['id']>275]
address5=address5_1[address5_1['id']<328]
address5.count()
# Out:
# id                      52
# collcetion_latest_id    52
# base_topic              52
# dst                     52
# src                     52
# seq                     52
# SNR                     52
# RSSIpkt                 52
# BW                      52
# CR                      52
# SF                      52
# sensor_id               52
# version                 52
# command_id              52
# data_length             52
# data                    52
# mote_lon                52
# mote_lat                52
# time                    52
# distance2base           52
# dtype: int64

# %%
address6_1=result[result['id']>327]
address6=address6_1[address6_1['id']<410]
address6.count()
# Out:
# id                      82
# collcetion_latest_id    82
# base_topic              82
# dst                     82
# src                     82
# seq                     82
# SNR                     82
# RSSIpkt                 82
# BW                      82
# CR                      82
# SF                      82
# sensor_id               82
# version                 82
# command_id              82
# data_length             82
# data                    82
# mote_lon                82
# mote_lat                82
# time                    82
# distance2base           82
# dtype: int64

# %%
# address6.head()
address6
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt   BW  \
# 327  328                    39  LTC-base1    1    2    1    8      -90  125
# 328  329                    39  LTC-base1    1    2    2    8      -94  125
# 329  330                    39  LTC-base1    1    2    3    8      -93  125
# 330  331                    39  LTC-base1    1    2    4    8      -95  125
# 331  332                    39  LTC-base1    1    2    5    8      -93  125
# 332  333                    39  LTC-base1    1    2    6    9      -92  125
# 333  334                    39  LTC-base1    1    2    7    8      -93  125
# 334  335                    39  LTC-base1    1    2    8    7      -98  125
# 335  336                    39  LTC-base1    1    2    9    8      -98  125
# 336  337                    39  LTC-base1    1    2    0    7      -94  125
# 337  338                    39  LTC-base1    1    2    1    8      -96  125
# ...

# %%
index_1=["id","collcetion_latest_id","base_topic" ,"dst" ,"src","seq" ,"SNR" , "RSSIpkt" ,"sensor_id",  "data_length", "data" , "time" , "distance2base"]
columns=index_1
address6_data = pd.DataFrame(address6,columns=index_1)
address6_data
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 327  328                    39  LTC-base1    1    2    1    8      -90
# 328  329                    39  LTC-base1    1    2    2    8      -94
# 329  330                    39  LTC-base1    1    2    3    8      -93
# 330  331                    39  LTC-base1    1    2    4    8      -95
# 331  332                    39  LTC-base1    1    2    5    8      -93
# 332  333                    39  LTC-base1    1    2    6    9      -92
# 333  334                    39  LTC-base1    1    2    7    8      -93
# 334  335                    39  LTC-base1    1    2    8    7      -98
# 335  336                    39  LTC-base1    1    2    9    8      -98
# 336  337                    39  LTC-base1    1    2    0    7      -94
# 337  338                    39  LTC-base1    1    2    1    8      -96
# 338  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
# address6['data'].max()
address6_data1=address6_data.replace([','],address6['data'].max())
address6_data1
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 327  328                    39  LTC-base1    1    2    1    8      -90
# 328  329                    39  LTC-base1    1    2    2    8      -94
# 329  330                    39  LTC-base1    1    2    3    8      -93
# 330  331                    39  LTC-base1    1    2    4    8      -95
# 331  332                    39  LTC-base1    1    2    5    8      -93
# 332  333                    39  LTC-base1    1    2    6    9      -92
# 333  334                    39  LTC-base1    1    2    7    8      -93
# 334  335                    39  LTC-base1    1    2    8    7      -98
# 335  336                    39  LTC-base1    1    2    9    8      -98
# 336  337                    39  LTC-base1    1    2    0    7      -94
# 337  338                    39  LTC-base1    1    2    1    8      -96
# 338  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
# address6_data2 = pd.DataFrame((x.split(',') for x in address6_data1.grade),index=address6_data1.index,columns=[ "mote_lon" , "mote_lat"])

address6_data2= pd.DataFrame((x.split(',') for x in address6_data1.data),index=address6_data1.index,columns=[ "mote_lon" , "mote_lat"])
address6_data2.dtypes
# Out:
# mote_lon    object
# mote_lat    object
# dtype: object

# %%
address6_data3=pd.merge(address6_data1,address6_data2,right_index=True, left_index=True)

# %%
address6_data3
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 327  328                    39  LTC-base1    1    2    1    8      -90
# 328  329                    39  LTC-base1    1    2    2    8      -94
# 329  330                    39  LTC-base1    1    2    3    8      -93
# 330  331                    39  LTC-base1    1    2    4    8      -95
# 331  332                    39  LTC-base1    1    2    5    8      -93
# 332  333                    39  LTC-base1    1    2    6    9      -92
# 333  334                    39  LTC-base1    1    2    7    8      -93
# 334  335                    39  LTC-base1    1    2    8    7      -98
# 335  336                    39  LTC-base1    1    2    9    8      -98
# 336  337                    39  LTC-base1    1    2    0    7      -94
# 337  338                    39  LTC-base1    1    2    1    8      -96
# 338  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
# address6_data3['data_length'].replace([1],address6_data3['data_length'].max())
# address6_data3.head()

# %%
# address6_data5 = pd.DataFrame((x.split(' ') for x in address6_data4.time),index=address6_data4.index,columns=['yyyy/MM/d','time'])

# %%
# address6_data5.head()

# %%
# address6_data6 = pd.DataFrame((x.split(':') for x in address6_data5.time),index=address6_data5.index,columns=['time3','time4'])
# address6_data6.head()

# %%
# address6_data7=pd.merge(address6_data4,address6_data5['yyyy/MM/d'],right_index=True, left_index=True)

# %%
# time1.astype(str)

# %%
# address6_data7=pd.merge(time1,address6_data5['yyyy/MM/d'],right_index=True, left_index=True)

# %%
# address6_data6['time4'].dtypes
# time1 = address6_data6['time3'].astype(int)
# time1 = time1 + 8
# time1

# %%
# address6_data5['channel_value']= address6_data4[address6_data4['src']==2]
address6_data5 = address6_data3[address6_data3['src']==2]
address6_data5['mote_code'] = 'M0002'
# Out:
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
address6_data5.head()
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 327  328                    39  LTC-base1    1    2    1    8      -90
# 328  329                    39  LTC-base1    1    2    2    8      -94
# 329  330                    39  LTC-base1    1    2    3    8      -93
# 330  331                    39  LTC-base1    1    2    4    8      -95
# 331  332                    39  LTC-base1    1    2    5    8      -93
#
#      sensor_id  data_length                  data            time  \
# 327          2            1  114.501403,36.571155  2017/7/25 9:00
# 328          2            1  114.501403,36.571155  2017/7/25 9:00
# 329          2            1  114.501403,36.571155  2017/7/25 9:00
# 330          2            1  114.501403,36.571155  2017/7/25 9:00
# 331          2            1  114.501403,36.571155  2017/7/25 9:00
#
#      distance2base    mote_lon   mote_lat mote_code
# 327     12200000.0  114.501403  36.571155     M0002
# ...

# %%
address6_data5['name'] = 'Mote_2_2017_7_25'
address6_data5['mode'] = 'c'
address6_data5['channel_value'] = '470'
address6_data5['power'] = '20'
# Out:
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
address6_data5['base_code'] = 'B0003'
address6_data5['server_id'] = '19'
# Out:
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
address6_data5
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 327  328                    39  LTC-base1    1    2    1    8      -90
# 328  329                    39  LTC-base1    1    2    2    8      -94
# 329  330                    39  LTC-base1    1    2    3    8      -93
# 330  331                    39  LTC-base1    1    2    4    8      -95
# 331  332                    39  LTC-base1    1    2    5    8      -93
# 332  333                    39  LTC-base1    1    2    6    9      -92
# 333  334                    39  LTC-base1    1    2    7    8      -93
# 334  335                    39  LTC-base1    1    2    8    7      -98
# 335  336                    39  LTC-base1    1    2    9    8      -98
# 336  337                    39  LTC-base1    1    2    0    7      -94
# 337  338                    39  LTC-base1    1    2    1    8      -96
# 338  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
address6_data5_3 = address6_data3[address6_data3['src']==3]
address6_data5_3['mote_code'] = 'M0003'
address6_data5_3.head()
# Out:
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 355  356                    38  LTC-base1    1    3    0    7      -86
# 356  357                    38  LTC-base1    1    3    1    8      -91
# 357  358                    38  LTC-base1    1    3    2   10      -87
# 358  359                    38  LTC-base1    1    3    3    8      -86
# 359  360                    38  LTC-base1    1    3    5    9      -89
#
#      sensor_id  data_length                  data            time  \
# 355          2           20  114.500163,36.571268  2017/7/25 9:01
# ...

# %%
address6_data5_3['name'] = 'Mote_3_2017_7_25'
address6_data5_3['mode'] = 'c'
address6_data5_3['channel_value'] = '470'
address6_data5_3['power'] = '20'
address6_data5_3['base_code'] = 'B0003'
address6_data5_3['server_id'] = '19'
# Out:
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
address6_data5_3.head()
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 355  356                    38  LTC-base1    1    3    0    7      -86
# 356  357                    38  LTC-base1    1    3    1    8      -91
# 357  358                    38  LTC-base1    1    3    2   10      -87
# 358  359                    38  LTC-base1    1    3    3    8      -86
# 359  360                    38  LTC-base1    1    3    5    9      -89
#
#      sensor_id  data_length    ...    distance2base    mote_lon   mote_lat  \
# 355          2           20    ...           1332.0  114.500163  36.571268
# 356          2           20    ...           1331.0  114.500162  36.571283
# 357          2           20    ...           1330.0  114.500172  36.571283
# 358          2           20    ...           1330.0  114.500183  36.571266
# 359          2           20    ...           1334.0  114.500163  36.571215
#
#     mote_code              name mode channel_value power base_code server_id
# ...

# %%
address6_data5_4 = address6_data3[address6_data3['src']==4]
address6_data5_4['mote_code'] = 'M0004'
address6_data5_4.head()
# Out:
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 380  381                    37  LTC-base1    1    4    0    8      -90
# 381  382                    37  LTC-base1    1    4    1    8      -93
# 382  383                    37  LTC-base1    1    4    2    7      -96
# 383  384                    37  LTC-base1    1    4    3    6     -109
# 384  385                    37  LTC-base1    1    4    4    8      -92
#
#      sensor_id  data_length                  data            time  \
# 380          2           20  114.500143,36.571265  2017/7/25 9:04
# ...

# %%
address6_data5_4['name'] = 'Mote_4_2017_7_25'
address6_data5_4['mode'] = 'c'
address6_data5_4['channel_value'] = '470'
address6_data5_4['power'] = '20'
address6_data5_4['base_code'] = 'B0003'
address6_data5_4['server_id'] = '19'
# Out:
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# f:\python\python3.5\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
address6_data5_4
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 380  381                    37  LTC-base1    1    4    0    8      -90
# 381  382                    37  LTC-base1    1    4    1    8      -93
# 382  383                    37  LTC-base1    1    4    2    7      -96
# 383  384                    37  LTC-base1    1    4    3    6     -109
# 384  385                    37  LTC-base1    1    4    4    8      -92
#
#      sensor_id  data_length    ...    distance2base    mote_lon   mote_lat  \
# 380          2           20    ...           1333.0  114.500143  36.571265
# 381          2           20    ...           1335.0  114.500126  36.571263
# 382          2           20    ...           1338.0  114.500105  36.571242
# 383          2           20    ...           1338.0  114.500083  36.571260
# 384          2           20    ...           1339.0  114.500079  36.571251
#
#     mote_code              name mode channel_value power base_code server_id
# ...

# %%
address6_data5.to_csv('address6_m2.csv',encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-710a2184c46b> in <module>()
# ----> 1 address6_data5.to_csv('address6_m2.csv',encoding='utf8')
#
# NameError: name 'address6_data5' is not defined

# %%
address6_data5_3.to_csv('address6_m3.csv',encoding='utf8')

# %%
address6_data5_4.to_csv('address6_m4.csv',encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-632066076e4d> in <module>()
# ----> 1 address6_data5_4.to_csv('address6_m4.csv',encoding='utf8')
#
# NameError: name 'address6_data5_4' is not defined

# %%
address6_all =[]

# %%
address6_all.append(address6_data5)

# %%
address6_all.append(address6_data5_3)

# %%
address6_all.append(address6_data5_4)

# %%
address6_all
# Out:
# [      id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
#  327  328                    39  LTC-base1    1    2    1    8      -90
#  328  329                    39  LTC-base1    1    2    2    8      -94
#  329  330                    39  LTC-base1    1    2    3    8      -93
#  330  331                    39  LTC-base1    1    2    4    8      -95
#  331  332                    39  LTC-base1    1    2    5    8      -93
#  332  333                    39  LTC-base1    1    2    6    9      -92
#  333  334                    39  LTC-base1    1    2    7    8      -93
#  334  335                    39  LTC-base1    1    2    8    7      -98
#  335  336                    39  LTC-base1    1    2    9    8      -98
#  336  337                    39  LTC-base1    1    2    0    7      -94
#  337  338                    39  LTC-base1    1    2    1    8      -96
#  338  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
csvs = pd.concat(address6_all, ignore_index = True)
csvs
# Out:
#      id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 0   328                    39  LTC-base1    1    2    1    8      -90
# 1   329                    39  LTC-base1    1    2    2    8      -94
# 2   330                    39  LTC-base1    1    2    3    8      -93
# 3   331                    39  LTC-base1    1    2    4    8      -95
# 4   332                    39  LTC-base1    1    2    5    8      -93
# 5   333                    39  LTC-base1    1    2    6    9      -92
# 6   334                    39  LTC-base1    1    2    7    8      -93
# 7   335                    39  LTC-base1    1    2    8    7      -98
# 8   336                    39  LTC-base1    1    2    9    8      -98
# 9   337                    39  LTC-base1    1    2    0    7      -94
# 10  338                    39  LTC-base1    1    2    1    8      -96
# 11  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
csvs['base_lon']='114.5137200000'
csvs['base_lat']='36.5762230000'
csvs.to_csv('address6_all_1.csv',encoding='utf')
csvs
# Out:
#      id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 0   328                    39  LTC-base1    1    2    1    8      -90
# 1   329                    39  LTC-base1    1    2    2    8      -94
# 2   330                    39  LTC-base1    1    2    3    8      -93
# 3   331                    39  LTC-base1    1    2    4    8      -95
# 4   332                    39  LTC-base1    1    2    5    8      -93
# 5   333                    39  LTC-base1    1    2    6    9      -92
# 6   334                    39  LTC-base1    1    2    7    8      -93
# 7   335                    39  LTC-base1    1    2    8    7      -98
# 8   336                    39  LTC-base1    1    2    9    8      -98
# 9   337                    39  LTC-base1    1    2    0    7      -94
# 10  338                    39  LTC-base1    1    2    1    8      -96
# 11  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
address6_all_RSS = csvs[ 'RSSIpkt']
address6_all_RSS.plot(figsize = (12,10))
ax=plt.gca()
ax.locator_params('x',nbins=40)

# %%
plt.scatter(address6_data5['id'],address6_data5['RSSIpkt'],c='g',label='RSSIpkt_mote2')
plt.scatter(address6_data5_3['id'],address6_data5_3['RSSIpkt'],c='r',label='RSSIpkt_mote3')
plt.scatter(address6_data5_4['id'],address6_data5_4['RSSIpkt'],c='y',label='RSSIpkt_mote4')
plt.legend(loc=1)
plt.title('Address6_RSSIpkt')
plt.figtext(0.4,-0.01,'time')
plt.figtext(-0.02,0.5,'RSSIpkt')
ax=plt.gca()
plt.grid(True)
ax.locator_params('x',nbins=30)
ax.locator_params('y',nbins=30)

# %%
csvs_2 = csvs[csvs['src']==2]

# %%
csvs_2
# Out:
#      id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 0   328                    39  LTC-base1    1    2    1    8      -90
# 1   329                    39  LTC-base1    1    2    2    8      -94
# 2   330                    39  LTC-base1    1    2    3    8      -93
# 3   331                    39  LTC-base1    1    2    4    8      -95
# 4   332                    39  LTC-base1    1    2    5    8      -93
# 5   333                    39  LTC-base1    1    2    6    9      -92
# 6   334                    39  LTC-base1    1    2    7    8      -93
# 7   335                    39  LTC-base1    1    2    8    7      -98
# 8   336                    39  LTC-base1    1    2    9    8      -98
# 9   337                    39  LTC-base1    1    2    0    7      -94
# 10  338                    39  LTC-base1    1    2    1    8      -96
# 11  339                    39  LTC-base1    1    2    2    8      -97
# ...

# %%
PER_2 = '%.2f'%((30-csvs_2['src'].count())/30)

# %%
PER_2
# Out:
# '0.07'

# %%
#箱型图： 上边缘，上四分位数，中位数 ，下四分位数 ， 下边缘 ，异常值
data2_RSS=csvs_2['RSSIpkt']
snr1 =[]
for i in data2_RSS:
    snr1.append(i)
snr1
plt.boxplot(snr1)
ax=plt.gca()
ax.locator_params('x',nbins=10)
ax.locator_params('y',nbins=20)

# %%
csvs_3 = csvs[csvs['src']==3]
data3_RSS=csvs_3['RSSIpkt']
snr2 =[]
for i in data3_RSS:
    snr2.append(i)
snr2
plt.boxplot(snr2)
ax=plt.gca()
ax.locator_params('x',nbins=10)
ax.locator_params('y',nbins=20)

# %%
csvs_4 = csvs[csvs['src']==4]
data4_RSS=csvs_4['RSSIpkt']
snr3 =[]
for i in data4_RSS:
    snr3.append(i)
snr3
plt.boxplot(snr3)
ax=plt.gca()
ax.locator_params('x',nbins=10)
ax.locator_params('y',nbins=20)

# %%
y=csvs_2['id']
plt.bar(height = data2_RSS,left=y)
# Out:
# <Container object of 28 artists>

# %%
y=csvs_3['id']
plt.bar(height = data3_RSS,left=y)
# Out:
# <Container object of 25 artists>

# %%
y=csvs_4['id']
plt.bar(height = data4_RSS,left=y)
# Out:
# <Container object of 29 artists>

# %%
y=csvs['id']
plt.bar(height =csvs['RSSIpkt'],left=y)
# Out:
# <Container object of 82 artists>

# %%
data2_RSS.describe().astype(np.int64).T
# Out:
# count    28
# mean    -94
# std       2
# min     -98
# 25%     -96
# 50%     -94
# 75%     -93
# max     -90
# Name: RSSIpkt, dtype: int64

# %%
data3_RSS.describe().astype(np.int64).T
# Out:
# count     25
# mean     -91
# std        5
# min     -108
# 25%      -95
# 50%      -90
# 75%      -87
# max      -85
# Name: RSSIpkt, dtype: int64

# %%
data4_RSS.describe().astype(np.int64).T
# Out:
# count     29
# mean     -85
# std       12
# min     -109
# 25%      -90
# 50%      -88
# 75%      -82
# max      -43
# Name: RSSIpkt, dtype: int64

# %%
csvs['RSSIpkt'].describe().astype(np.int64).T  # std  标准差  var  方差
# Out:
# count     82
# mean     -90
# std        9
# min     -109
# 25%      -94
# 50%      -91
# 75%      -87
# max      -43
# Name: RSSIpkt, dtype: int64

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
y=csvs_2['id']
ax1.bar(height = data2_RSS,left=y)
y=csvs_3['id']
ax2.bar(height = data3_RSS,left=y)
y=csvs_4['id']
ax3.bar(height = data4_RSS,left=y)
# Out:
# <Container object of 29 artists>

# %%
fig

# %%
# fig_3 = plt.figure()

hetu_3 = fig_3.add_subplot(2,2,1)
sandian_3 = fig_3.add_subplot(2,2,2)
tiao_3 = fig_3.add_subplot(2,2,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-178ab518b70e> in <module>()
#       1 # fig_3 = plt.figure()
#       2
# ----> 3 hetu_3 = fig_3.add_subplot(2,2,1)
#       4 sandian_3 = fig_3.add_subplot(2,2,2)
#       5 tiao_3 = fig_3.add_subplot(2,2,3)
#
# NameError: name 'fig_3' is not defined

# %%
sandian_3.scatter(address6_data5_4['id'],address6_data5_4['RSSIpkt'],c='r',label='RSSIpkt_mote3')
y=csvs_4['id']
tiao_3.bar(height = data4_RSS,left=y)
hetu_3.boxplot(snr4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5499b7354f35> in <module>()
# ----> 1 sandian_3.scatter(address6_data5_4['id'],address6_data5_4['RSSIpkt'],c='r',label='RSSIpkt_mote3')
#       2 y=csvs_4['id']
#       3 tiao_3.bar(height = data4_RSS,left=y)
#       4 hetu_3.boxplot(snr4)
#
# NameError: name 'sandian_3' is not defined

# %%
#在某个位置 3 号 mote的 信号强度 的  盒图   散点图  条形图
fig_3

# %%
# fig_m = plt.figure()
m_2 = fig_m.add_subplot(2,2,1)
m_3 = fig_m.add_subplot(2,2,2)
m_4 = fig_m.add_subplot(2,2,3)

# %%
m_2.scatter(address6_data5['id'],address6_data5['RSSIpkt'],c='r',label='RSSIpkt_mote2')
m_3.scatter(address6_data5_3['id'],address6_data5_3['RSSIpkt'],c='g',label='RSSIpkt_mote3')
m_4.scatter(address6_data5_4['id'],address6_data5_4['RSSIpkt'],c='y',label='RSSIpkt_mote4')

# %%
#在某个位置  3 个Mote 的信号强度散点图
fig_m

# %%
# fig_address6_all = plt.figure()

hetu_all = fig_address6_all.add_subplot(2,2,1)
sandian_all = fig_address6_all.add_subplot(2,2,2)
tiao_all = fig_address6_all.add_subplot(2,2,3)

# %%
sandian_all.scatter(csvs['id'],csvs['RSSIpkt'],c='r',label='RSSIpkt')
y=csvs['id']
tiao_all.bar(height =csvs['RSSIpkt'],left=y)
hetu_all.boxplot(csvs['RSSIpkt'])
fig_address6_all  # 某个位置三台 mote 信号强度的  盒图   散点图   条形图
