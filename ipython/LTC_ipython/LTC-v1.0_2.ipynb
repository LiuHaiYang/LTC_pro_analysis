# %%
# %matplotlib inline
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymongo

# %%
index =["baseTopic" , "dst" , "src" , "seq" , "SNR" , "RSSIpkt" , "BW" , "CR" , "SF" , "sensor_id" , "version", "command_id", "data_length" , "data" , "mote_lon" , "mote_lat" , "time" ]
ltc_data = pd.read_csv('ltc_v1.0_100.csv',sep=',')
ltc_data.head()
# Out:
#    Unnamed: 0  baseTopic  dst  src  seq  SNR  RSSIpkt   BW   CR  SF  \
# 0           0  LTC-base1    1    7    3    7      -96  125  4/5  12
# 1           1  LTC-base1    1    7    0    7     -101  125  4/5  12
# 2           2  LTC-base1    1    7    1    7     -100  125  4/5  12
# 3           3  LTC-base1    1    7    2    7     -101  125  4/5  12
# 4           4  LTC-base1    1    7    4    5     -103  125  4/5  12
#
#    sensor_id  version  command_id  data_length data  mote_lon  mote_lat  \
# 0          2        1           9            1    ,         0         0
# 1          2        1           9            1    ,         0         0
# 2          2        1           9            1    ,         0         0
# 3          2        1           9            1    ,         0         0
# 4          2        1           9            1    ,         0         0
#
#                   time
# 0  2017-07-17 18:18:19
# 1  2017-07-17 18:20:00
# 2  2017-07-17 18:20:04
# 3  2017-07-17 18:24:58
# ...

# %%
index1=["baseTopic" , "dst" , "src" , "seq" , "SNR" , "RSSIpkt" , "BW" , "CR" , "SF" , "sensor_id" , "version", "command_id", "data_length" , "data" , "mote_lon" , "mote_lat" , "time" ]
result_1 = pd.DataFrame(ltc_data,columns=index1)
result_1
# Out:
#      baseTopic  dst  src  seq  SNR  RSSIpkt   BW   CR  SF  sensor_id  version  \
# 0    LTC-base1    1    7    3    7      -96  125  4/5  12          2        1
# 1    LTC-base1    1    7    0    7     -101  125  4/5  12          2        1
# 2    LTC-base1    1    7    1    7     -100  125  4/5  12          2        1
# 3    LTC-base1    1    7    2    7     -101  125  4/5  12          2        1
# 4    LTC-base1    1    7    4    5     -103  125  4/5  12          2        1
# 5    LTC-base1    1    7    6    5     -100  125  4/5  12          2        1
# 6    LTC-base1    1    7    7    6     -102  125  4/5  12          2        1
# 7    LTC-base1    1    7    8    7      -99  125  4/5  12          2        1
# 8    LTC-base1    1    7    9    8      -99  125  4/5  12          2        1
# 9    LTC-base1    1    7   10    6      -99  125  4/5  12          2        1
# 10   LTC-base1    1    7   11    7      -99  125  4/5  12          2        1
# ...

# %%
# ltc_data.dtypes
# ltc_data['Unnamed: 0']=ltc_data['Unnamed: 0'].astype(np.int64)
# ltc_data['Unnamed: 0' > 1]
data1 = ltc_data[ltc_data['Unnamed: 0']> 0]
data2=data1[data1['Unnamed: 0']<61]
data2
data2['seq'].count()
# Out:
#     Unnamed: 0  baseTopic  dst  src  seq  SNR  RSSIpkt   BW   CR  SF  \
# 1            1  LTC-base1    1    7    0    7     -101  125  4/5  12
# 2            2  LTC-base1    1    7    1    7     -100  125  4/5  12
# 3            3  LTC-base1    1    7    2    7     -101  125  4/5  12
# 4            4  LTC-base1    1    7    4    5     -103  125  4/5  12
# 5            5  LTC-base1    1    7    6    5     -100  125  4/5  12
# 6            6  LTC-base1    1    7    7    6     -102  125  4/5  12
# 7            7  LTC-base1    1    7    8    7      -99  125  4/5  12
# 8            8  LTC-base1    1    7    9    8      -99  125  4/5  12
# 9            9  LTC-base1    1    7   10    6      -99  125  4/5  12
# 10          10  LTC-base1    1    7   11    7      -99  125  4/5  12
# 11          11  LTC-base1    1    7   14    7     -100  125  4/5  12
# 12          12  LTC-base1    1    7   15    7      -99  125  4/5  12
# 13          13  LTC-base1    1    7   17    5     -101  125  4/5  12
# ...

# %%
rec_count=data2['seq'].count()
all_count=data2['seq'].max()+1
# miss_pack = data2['seq'].count()/data2['seq'].max()
miss_pack=(rec_count/all_count)*100
# rec_count
# all_count
miss_pack
# Out:
# 60

# %%
data1 = ltc_data[ltc_data['Unnamed: 0']> 0]
data2=data1[data1['Unnamed: 0']<61]
rec_count=data2['seq'].count()
all_count=data2['seq'].max()+1
miss_pack=(rec_count/all_count)*100
miss_pack
# Out:
# 65.934065934065927

# %%
data_seq= ltc_data[ltc_data['seq']==0]   #判断初始化位置
data_seq
# Out:
#      Unnamed: 0  baseTopic  dst  src  seq  SNR  RSSIpkt   BW   CR  SF  \
# 1             1  LTC-base1    1    7    0    7     -101  125  4/5  12
# 61           61  LTC-base1    1    7    0    8      -87  125  4/5  12
# 68           68  LTC-base1    1    7    0    7     -101  125  4/5  12
# 72           72  LTC-base1    1    7    0    2     -107  125  4/5  12
# 73           73  LTC-base1    1    7    0    5     -103  125  4/5  12
# 76           76  LTC-base1    1    7    0    6     -102  125  4/5  12
# 78           78  LTC-base1    1    7    0    5     -103  125  4/5  12
# 84           84  LTC-base1    1    7    0    7     -100  125  4/5  12
# 88           88  LTC-base1    1    7    0    3     -105  125  4/5  12
# 116         116  LTC-base1    1    7    0    8      -27  125  4/5  12
#
#      sensor_id  version  command_id  data_length data  mote_lon  mote_lat  \
# 1            2        1           9            1    ,         0         0
# ...

# %%
data3 = ltc_data[ltc_data['Unnamed: 0']> 60]
data4=data3[data3['Unnamed: 0']<68]
rec_count=data4['seq'].count()
all_count=data4['seq'].max()+1
miss_pack=(rec_count/all_count)*100
miss_pack
# Out:
# 100.0

# %%
data3 = ltc_data[ltc_data['Unnamed: 0']> 69]
data4=data3[data3['Unnamed: 0']<72]
rec_count=data4['seq'].count()
all_count=data4['seq'].max()+1
miss_pack=(rec_count/all_count)*100
miss_pack
# Out:
# 22.222222222222221

# %%
data3 = ltc_data[ltc_data['Unnamed: 0']> 72]
data4=data3[data3['Unnamed: 0']<76]

rec_count=data4['seq'].count()
all_count=data4['seq'].max()+1
miss_pack=(rec_count/all_count)*100
miss_pack
# Out:
# 33.333333333333329

# %%
data3 = ltc_data[ltc_data['Unnamed: 0']> 83]
data4=data3[data3['Unnamed: 0']<88]

rec_count=data4['seq'].count()
all_count=data4['seq'].max()+1
miss_pack=(rec_count/all_count)*100
miss_pack
# Out:
# 26.666666666666668

# %%
# 存在异常值
data3 = ltc_data[ltc_data['Unnamed: 0']> 87]
data4=data3[data3['Unnamed: 0']<116]

rec_count=data4['seq'].count()
all_count=data4['seq'].max()+1
miss_pack=(rec_count/all_count)*100
miss_pack
# Out:
# 25.688073394495415

# %%
data3 = ltc_data[ltc_data['Unnamed: 0']> 115]
data4=data3[data3['Unnamed: 0']<124]

rec_count=data4['seq'].count()
all_count=data4['seq'].max()+1
miss_pack=(rec_count/all_count)*100
miss_pack
# Out:
# 31.818181818181817
