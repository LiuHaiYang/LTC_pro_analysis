# %%
# %matplotlib inline
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
index =["baseTopic" , "dst" , "src" , "seq" , "SNR" , "RSSIpkt" , "BW" , "CR" , "SF" , "sensor_id" , "version", "command_id", "data_length" , "data" , "mote_lon" , "mote_lat" , "time" ]
ltc_data = pd.read_csv('ltc_v1.0_100.csv',sep=',')
ltc_data.head()
# Out:
#    Unnamed: 0  baseTopic  dst  src  seq  SNR  RSSIpkt   BW   CR  SF  \
# 0           0  LTC-base1    1    7    3    7      -96  125  4/5  12
# 1           1  LTC-base1    1    7    0    7     -101  125  4/5  12
# 2           2  LTC-base1    1    7    1    7     -100  125  4/5  12
# 3           3  LTC-base1    1    7    2    7     -101  125  4/5  12
# 4           4  LTC-base1    1    7    4    5     -103  125  4/5  12
#
#    sensor_id  version  command_id  data_length data  mote_lon  mote_lat  \
# 0          2        1           9            1    ,         0         0
# 1          2        1           9            1    ,         0         0
# 2          2        1           9            1    ,         0         0
# 3          2        1           9            1    ,         0         0
# 4          2        1           9            1    ,         0         0
#
#                   time
# 0  2017-07-17 18:18:19
# 1  2017-07-17 18:20:00
# 2  2017-07-17 18:20:04
# 3  2017-07-17 18:24:58
# ...

# %%
data1 = ltc_data[ltc_data['Unnamed: 0']> 0]
data2=data1[data1['Unnamed: 0']<61]
data2
# Out:
#     Unnamed: 0  baseTopic  dst  src  seq  SNR  RSSIpkt   BW   CR  SF  \
# 1            1  LTC-base1    1    7    0    7     -101  125  4/5  12
# 2            2  LTC-base1    1    7    1    7     -100  125  4/5  12
# 3            3  LTC-base1    1    7    2    7     -101  125  4/5  12
# 4            4  LTC-base1    1    7    4    5     -103  125  4/5  12
# 5            5  LTC-base1    1    7    6    5     -100  125  4/5  12
# 6            6  LTC-base1    1    7    7    6     -102  125  4/5  12
# 7            7  LTC-base1    1    7    8    7      -99  125  4/5  12
# 8            8  LTC-base1    1    7    9    8      -99  125  4/5  12
# 9            9  LTC-base1    1    7   10    6      -99  125  4/5  12
# 10          10  LTC-base1    1    7   11    7      -99  125  4/5  12
# 11          11  LTC-base1    1    7   14    7     -100  125  4/5  12
# 12          12  LTC-base1    1    7   15    7      -99  125  4/5  12
# 13          13  LTC-base1    1    7   17    5     -101  125  4/5  12
# ...

# %%
#箱型图： 上边缘，上四分位数，中位数 ，下四分位数 ， 下边缘 ，异常值
data_SNR=data2['SNR']

snr =[]
for i in data_SNR:
    snr.append(i)
snr
# labels= ['SNR']
plt.boxplot(snr)
ax=plt.gca()
ax.locator_params('x',nbins=10)
ax.locator_params('y',nbins=20)

# %%
# data=np.random.normal(size=1000,loc=0,scale=1)
# data
# plt.boxplot(data)
# Out:
# array([ -9.00738337e-01,  -9.24641765e-01,  -2.36930713e+00,
#         -8.09539226e-01,   1.33758501e+00,  -3.09752471e-01,
#         -1.94913125e+00,  -1.49239580e+00,  -1.27619052e+00,
#          6.31826926e-01,   9.86568690e-01,   2.80654761e+00,
#         -1.77061945e-01,  -8.34944654e-01,   1.37344846e+00,
#          5.52606209e-01,   6.82285140e-01,  -1.76830764e-01,
#          1.22888202e-01,  -3.94023775e-01,  -3.60319869e+00,
#          8.95169684e-01,   5.83605114e-01,  -1.60222458e+00,
#         -8.06592971e-01,  -2.66580814e-01,   3.68213534e-01,
#         -3.26132080e-01,  -8.85354691e-01,  -1.00121842e+00,
#         -7.09817511e-01,  -6.86951577e-01,  -2.89038847e-01,
#         -6.63183195e-01,   5.03384333e-01,  -8.03481293e-01,
#          1.53724850e+00,  -5.98217015e-01,  -1.13774968e+00,
#         -2.02358150e-01,   3.67685877e-01,   1.61792456e+00,
#         -2.42763276e-01,  -4.12711029e-01,   1.99024890e-01,
# ...

# %%
data_RSSIpkt=data2['RSSIpkt']
rss =[]
for i in data_RSSIpkt:
    rss.append(i)
rss
plt.boxplot(rss)
ax=plt.gca()
ax.locator_params('x',nbins=10)
ax.locator_params('y',nbins=20)

# %%
# data_RSSIpkt.describe().astype(np.int64).T
data_SNR.describe().astype(np.int64).T
# Out:
# count    60
# mean      6
# std       2
# min      -3
# 25%       5
# 50%       7
# 75%       8
# max       9
# Name: SNR, dtype: int64

# %%
data_RS=data2[['RSSIpkt','SNR']]
data_RS
# data_all =[]
# for i in data_RS:
#     data_all.append(i)
# data_all
# plt.boxplot(rss)
# Out:
#     RSSIpkt  SNR
# 1      -101    7
# 2      -100    7
# 3      -101    7
# 4      -103    5
# 5      -100    5
# 6      -102    6
# 7       -99    7
# 8       -99    8
# 9       -99    6
# 10      -99    7
# 11     -100    7
# 12      -99    7
# 13     -101    5
# 14     -102    5
# 15     -103    4
# 16     -102    5
# 17     -103    5
# 18     -103    4
# 19     -101    6
# 20     -102    5
# 21     -102    5
# 22     -101    5
# 23     -101    7
# 24     -100    6
# 25     -100    6
# 26      -91    8
# 27      -95    8
# 28      -94    8
# 29      -95    8
# 30      -97    7
# 31      -92    8
# 32      -92    7
# 33      -88    8
# 34     -105    3
# 35     -108    0
# 36     -104    3
# 37     -105    3
# 38      -47   -2
# 39      -48   -3
# 40     -104    4
# 41      -97    7
# 42     -101    6
# 43      -98    6
# 44     -104    4
# 45     -101    4
# 46      -97    7
# 47     -101    6
# 48      -93    7
# 49      -93    7
# 50      -90    9
# 51      -90    9
# ...
