# %%
# %matplotlib inline
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
result = pd.read_csv('D:\pandas\pandas_work\ipython\LTC_Data_Test\LTC_v1.0_data_7_26_1.csv',sep=',')
result.head()
# Out:
#    Unnamed: 0  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 0           0                    45  LTC-base1    1    5    0    8      -98
# 1           1                    45  LTC-base1    1    5    1    8      -94
# 2           2                    45  LTC-base1    1    5    2    8      -94
# 3           3                    45  LTC-base1    1    5    4    8      -93
# 4           4                    45  LTC-base1    1    5    5    8      -96
#
#    sensor_id              data_new  data_length    mote_lon   mote_lat  \
# 0          5  114.500082,36.571301           20  114.500082  36.571301
# 1          5  114.500088,36.571312           20  114.500088  36.571312
# 2          5  114.500092,36.571312           20  114.500092  36.571312
# 3          5  114.500099,36.571323           20  114.500099  36.571323
# 4          5  114.500102,36.571331           20  114.500102  36.571331
#
#              time  distance2base
# 0  2017/7/26 7:59         1202.0
# ...

# %%
Data_m_5 = result[result['src']==5]
Data_m_5
# Out:
#      Unnamed: 0  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 0             0                    45  LTC-base1    1    5    0    8      -98
# 1             1                    45  LTC-base1    1    5    1    8      -94
# 2             2                    45  LTC-base1    1    5    2    8      -94
# 3             3                    45  LTC-base1    1    5    4    8      -93
# 4             4                    45  LTC-base1    1    5    5    8      -96
# 5             5                    45  LTC-base1    1    5    6    8      -94
# 6             6                    45  LTC-base1    1    5    7    8      -95
# 7             7                    45  LTC-base1    1    5    8    9      -95
# 8             8                    45  LTC-base1    1    5    9    8      -96
# 9             9                    45  LTC-base1    1    5   10    8     -102
# 10           10                    45  LTC-base1    1    5   11    9     -103
# ...

# %%
Data_m_6 = result[result['src']==6]
Data_m_6.head(50)
# Out:
#      Unnamed: 0  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 255         255                    41  LTC-base1    1    6    0    8     -104
# 256         256                    41  LTC-base1    1    6    0    8     -103
# 257         257                    41  LTC-base1    1    6    1    9     -103
# 258         258                    41  LTC-base1    1    6    2    8     -106
# 259         259                    41  LTC-base1    1    6    3    9     -106
# 260         260                    41  LTC-base1    1    6    4    8     -108
# 261         261                    41  LTC-base1    1    6    5    8     -108
# 262         262                    41  LTC-base1    1    6    6    5     -115
# 263         263                    41  LTC-base1    1    6    7    9     -104
# 264         264                    41  LTC-base1    1    6    8    9     -105
# 265         265                    41  LTC-base1    1    6    9    8     -106
# ...

# %%
Data_m_7 = result[result['src']==7]
Data_m_7
# Out:
#      Unnamed: 0  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 514         514                    43  LTC-base1    1    7    0    7     -111
# 515         515                    43  LTC-base1    1    7    1    7     -110
# 516         516                    43  LTC-base1    1    7    2    7     -112
# 517         517                    43  LTC-base1    1    7    3    7     -112
# 518         518                    43  LTC-base1    1    7    4    7     -111
# 519         519                    43  LTC-base1    1    7    5    7     -111
# 520         520                    43  LTC-base1    1    7    6    7     -113
# 521         521                    43  LTC-base1    1    7    7    3     -116
# 522         522                    43  LTC-base1    1    7    8    4     -114
# 523         523                    43  LTC-base1    1    7    9    7     -111
# 524         524                    43  LTC-base1    1    7   10    8     -104
# ...

# %%
Ads_A_m_5 = Data_m_5[Data_m_5['seq']>1]
Ads_A_m_5_1 = Ads_A_m_5[Ads_A_m_5['seq']<48]
a = Ads_A_m_5_1['seq'].count()
# a
PER_A_5 = '%.2f'%(((46-a)/46)*100)
PER_A_5
# Out:
# '8.70'

# %%
Ads_B_m_5 = Data_m_5[Data_m_5['seq']>52]
Ads_B_m_5_1 = Ads_B_m_5[Ads_B_m_5['seq']<99]
a = Ads_B_m_5_1['seq'].count()
# a
PER_B_5 = '%.2f'%(((46-a)/46)*100)
PER_B_5
# Out:
# '2.17'

# %%
Ads_C_m_5 = Data_m_5[Data_m_5['seq']>106]
Ads_C_m_5_1 = Ads_C_m_5[Ads_C_m_5['seq']<153]
a = Ads_C_m_5_1['seq'].count()
# a
PER_C_5 = '%.2f'%(((46-a)/46)*100)
PER_C_5
# Out:
# '4.35'

# %%
Ads_D_m_5 = Data_m_5[Data_m_5['seq']>161]
Ads_D_m_5_1 = Ads_D_m_5[Ads_D_m_5['seq']<208]
a = Ads_D_m_5_1['seq'].count()
# a
PER_D_5 = '%.2f'%(((46-a)/46)*100)
PER_D_5
# Out:
# '2.17'

# %%
Ads_E_m_5 = Data_m_5[Data_m_5['seq']>214]
Ads_E_m_5_1 = Ads_E_m_5[Ads_E_m_5['seq']<261]
a = Ads_E_m_5_1['seq'].count()
# a
PER_E_5 = '%.2f'%(((46-a)/46)*100)
PER_E_5
# Out:
# '2.17'

# %%
Ads_A_m_6 = Data_m_6[Data_m_6['seq']>1]
Ads_A_m_6_1 = Ads_A_m_6[Ads_A_m_6['seq']<48]
a = Ads_A_m_6_1['seq'].count()
# a
PER_A_6 = '%.2f'%(((46-a)/46)*100)
PER_A_6
# Out:
# '0.00'

# %%
Ads_B_m_6 = Data_m_6[Data_m_6['seq']>52]
Ads_B_m_6_1 = Ads_B_m_6[Ads_B_m_6['seq']<99]
a = Ads_B_m_6_1['seq'].count()
# a
PER_B_6 = '%.2f'%(((46-a)/46)*100)
PER_B_6
# Out:
# '0.00'

# %%
Ads_C_m_6 = Data_m_6[Data_m_6['seq']>106]
Ads_C_m_6_1 = Ads_C_m_6[Ads_C_m_6['seq']<153]
a = Ads_C_m_6_1['seq'].count()
# a
PER_C_6 = '%.2f'%(((46-a)/46)*100)
PER_C_6
# Out:
# '8.70'

# %%
Ads_D_m_6 = Data_m_6[Data_m_6['seq']>161]
Ads_D_m_6_1 = Ads_D_m_6[Ads_D_m_6['seq']<208]
a = Ads_D_m_6_1['seq'].count()
# a
PER_D_6 = '%.2f'%(((46-a)/46)*100)
PER_D_6
# Ads_D_m_5_1
# Out:
# '0.00'

# %%
Ads_E_m_6 = Data_m_6[Data_m_6['seq']>214]
Ads_E_m_6_1 = Ads_E_m_6[Ads_E_m_6['seq']<261]
a = Ads_E_m_6_1['seq'].count()
# a
PER_E_6 = '%.2f'%(((46-a)/46)*100)
PER_E_6
# Out:
# '0.00'

# %%
Ads_A_m_7 = Data_m_7[Data_m_7['seq']>1]
Ads_A_m_7_1 = Ads_A_m_7[Ads_A_m_7['seq']<48]
a = Ads_A_m_7_1['seq'].count()
# a
PER_A_7 = '%.2f'%(((46-a)/46)*100)
# PER_A_7
Ads_A_m_7_1
# Out:
#      Unnamed: 0  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt  \
# 516         516                    43  LTC-base1    1    7    2    7     -112
# 517         517                    43  LTC-base1    1    7    3    7     -112
# 518         518                    43  LTC-base1    1    7    4    7     -111
# 519         519                    43  LTC-base1    1    7    5    7     -111
# 520         520                    43  LTC-base1    1    7    6    7     -113
# 521         521                    43  LTC-base1    1    7    7    3     -116
# 522         522                    43  LTC-base1    1    7    8    4     -114
# 523         523                    43  LTC-base1    1    7    9    7     -111
# 524         524                    43  LTC-base1    1    7   10    8     -104
# 525         525                    43  LTC-base1    1    7   11    9     -104
# 526         526                    43  LTC-base1    1    7   12    8     -102
# ...

# %%
Ads_B_m_7 = Data_m_7[Data_m_7['seq']>52]
Ads_B_m_7_1 = Ads_B_m_7[Ads_B_m_7['seq']<99]
a = Ads_B_m_7_1['seq'].count()
# a
PER_B_7 = '%.2f'%(((46-a)/46)*100)
PER_B_7
# Out:
# '0.00'

# %%
Ads_C_m_7 = Data_m_7[Data_m_7['seq']>106]
Ads_C_m_7_1 = Ads_C_m_7[Ads_C_m_7['seq']<153]
a = Ads_C_m_7_1['seq'].count()
# a
PER_C_7 = '%.2f'%(((46-a)/46)*100)
PER_C_7
# Out:
# '6.52'

# %%
Ads_D_m_7 = Data_m_7[Data_m_7['seq']>161]
Ads_D_m_7_1 = Ads_D_m_7[Ads_D_m_7['seq']<208]
a = Ads_D_m_7_1['seq'].count()
# a
PER_D_7 = '%.2f'%(((46-a)/46)*100)
PER_D_7
# Ads_D_m_5_1
# Out:
# '0.00'

# %%
Ads_E_m_7 = Data_m_7[Data_m_7['seq']>214]
Ads_E_m_7_1 = Ads_E_m_7[Ads_E_m_7['seq']<261]
a = Ads_E_m_7_1['seq'].count()
# a
PER_E_7 = '%.2f'%(((46-a)/46)*100)
PER_E_7
# Out:
# '0.00'

# %%
indxA_y = [2,3,4]
indxA_x = [PER_D_5,PER_D_6,PER_D_7]
# indxA_x = [22,23,10]
# indxB_y = [7,8,9]
# indxA_x =[PER_C_5,PER_C_6,PER_C_7]
# indxC_y = [12,13,14]
# indxA_x = [PER_E_5,PER_E_6,PER_E_7]
# indxD_y = [17,18,19]
# indxA_x = [PER_B_5,PER_B_6,PER_B_7]
# indxE_y = [22,23,24]
# indxA_x = [PER_A_5,PER_A_6,PER_A_7]

plt.bar(left=indxA_y,height=indxA_x)
# plt.bar(left=indxB_y,height=indxB_x)
# plt.bar(left=indxC_y,height=indxC_x)
# plt.bar(left=indxD_y,height=indxD_x)
# plt.bar(left=indxE_y,height=indxE_x)
# Out:
# <Container object of 3 artists>

# %%
float(PER_D_5)
# Out:
# 2.17

# %%
indx5_y = [2,7,12,17,22]       
indx6_y = [3,8,13,18,23]
indx7_y = [4,9,14,19,24]

indx5_x =  [ float(PER_D_5),float(PER_C_5),float(PER_E_5),float(PER_B_5),float(PER_A_5)]
indx6_x =  [ float(PER_D_6),float(PER_C_6),float(PER_E_6),float(PER_B_6),float(PER_A_6)]
indx7_x =  [ float(PER_D_7),float(PER_C_7),float(PER_E_7),float(PER_B_7),float(PER_A_7)]
axHisX = plt.bar(left=indx5_y,height=indx5_x,color='r',label='Mote_5')
axHisX =plt.bar(left=indx6_y,height=indx6_x,color='g',label='Mote_6')
axHisX =plt.bar(left=indx7_y,height=indx7_x,color='b',label='Mote_7')
plt.legend(loc=2)
plt.title('PER')
# figure=(130,30)
plt.axis([1,26,0,100])
plt.figtext(0.18,0.05,'D')
plt.figtext(0.35,0.05,'C')
plt.figtext(0.51,0.05,'E')
plt.figtext(0.67,0.05,'B')
plt.figtext(0.81,0.05,'A')
plt.figtext(-0.01,0.86,'PER/%')
ax=plt.gca()
plt.grid(True)
ax.locator_params('x',nbins=1)
ax.locator_params('y',nbins=30)
# plt.figure(figsize=(30,30))
