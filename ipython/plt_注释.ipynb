# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x =np.arange(-10,11,1)

# %%
y = x*x

# %%
y
# Out:
# array([100,  81,  64,  49,  36,  25,  16,   9,   4,   1,   0,   1,   4,
#          9,  16,  25,  36,  49,  64,  81, 100])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.annotate('this is the nottom',xy=(0,1),xytext=(0,20),arrowprops=dict(facecolor='g',frac=0.2))
# Out:
# C:\Users\samsung1\AppData\Roaming\Python\Python35\site-packages\matplotlib\text.py:2242: UserWarning: 'frac' option in 'arrowprops' is no longer supported; use 'headlength' to set the head length in points.
#   "'frac' option in 'arrowprops' is no longer supported;"
