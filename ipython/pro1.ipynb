# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pymysql

# %%
con = create_engine('mysql+pymysql://root:843800695@localhost:3306/target')
index_one = ['Target_ID','Pin_ID','Target_Access_DT','Target_Priority','Target_Web_live_long','Target_Rec_DT','Target_Signal']
data = pd.read_sql_table('target_rec',con,columns=index_one)

# %%
index_one = data[['Pin_ID','Target_Access_DT','Target_Priority','Target_Web_live_long','Target_Rec_DT','Target_Signal']]
date2 = index_one
date2
# Out:
#       Pin_ID    Target_Access_DT    Target_Priority  Target_Web_live_long  \
# 0        100 2016-11-02 06:47:58  6C-25-B9-77-EE-6C                  7530
# 1        100 2016-11-01 20:20:21  68-3E-34-13-06-6B                 45187
# 2        100 2016-11-02 07:32:04  18-59-36-8C-C6-BC                  4884
# 3        100 2016-11-02 08:10:45  1C-3E-84-0F-A2-17                  2563
# 4        100 2016-11-02 08:17:11  F4-29-81-BF-CE-09                  2177
# 5        100 2016-11-02 08:44:24  24-00-BA-07-9D-C7                   544
# 6        101 2016-11-02 08:33:39  28-E3-1F-7F-4F-F4                  1189
# 7        101 2016-11-02 08:50:01  90-21-81-F4-03-AB                   207
# 8        101 2016-11-02 08:50:20  7C-1D-D9-BA-D1-E3                   188
# 9        102 2016-11-02 07:47:55  38-BC-1A-D6-3B-FC                  3933
# 10       102 2016-11-02 08:43:02  CC-C7-60-2B-0A-7A                   626
# 11       104 2016-11-02 08:35:06  90-B6-86-D7-B4-7C                  1102
# ...

# %%
data3 = date2[date2.Target_Signal != '0']
data4 = data3[['Pin_ID','Target_Priority']]
data4
# Out:
#       Pin_ID    Target_Priority
# 0        100  6C-25-B9-77-EE-6C
# 3        100  1C-3E-84-0F-A2-17
# 4        100  F4-29-81-BF-CE-09
# 5        100  24-00-BA-07-9D-C7
# 7        101  90-21-81-F4-03-AB
# 8        101  7C-1D-D9-BA-D1-E3
# 10       102  CC-C7-60-2B-0A-7A
# 11       104  90-B6-86-D7-B4-7C
# 13       104  24-DF-6A-84-03-22
# 14       104  D0-33-11-3D-04-75
# 15       104  48-6B-2C-63-8F-0C
# 16       104  A8-1B-5A-67-67-15
# 17       104  FC-64-BA-83-52-50
# 19       105  40-33-1A-F1-EE-E8
# 20       106  9C-D2-1E-FD-BE-C9
# 21       107  68-3E-34-28-1E-94
# 23       107  C8-25-E1-D7-4C-FF
# 24       107  38-BC-1A-D1-97-C8
# 25       107  DC-37-14-B9-43-BA
# 26       107  74-51-BA-DC-4E-3C
# 27       107  00-9A-CD-78-02-1B
# 29       109  20-82-C0-74-C1-B7
# 30       109  44-33-4C-3A-6A-67
# 31       109  38-A4-ED-05-1B-F3
# 32       109  40-16-9F-83-9F-F9
# 33       109  34-80-B3-88-58-09
# 34       109  40-C6-2A-22-CA-42
# 35       110  14-F6-5A-AD-02-2D
# ...

# %%
data4['Pin_ID'].drop_duplicates().count()
# Out:
# 18

# %%
data4['Target_Priority'].drop_duplicates().count()
# Out:
# 82

# %%
data3 = date2[date2.Target_Signal != '0']


fd = data3.groupby([data3['Target_Priority'], data3['Pin_ID']]).size()
fs = fd.unstack().T.fillna(value=0)
fs
# Out:
# Index(['00-08-CA-6D-17-DA', '00-19-E0-87-5A-87', '00-9A-CD-78-02-1B',
#        '00-BB-3A-C5-E5-63', '04-02-1F-29-1B-F3', '08-EE-8B-DF-4E-EB',
#        '10-2A-B3-4A-96-83', '10-2A-B3-E5-EC-7D', '14-F6-5A-AD-02-2D',
#        '18-DC-56-D0-31-39', '1C-3E-84-0F-A2-17', '1C-67-58-EA-B8-28',
#        '20-82-C0-74-C1-B7', '20-82-C0-D9-46-E1', '24-00-BA-07-9D-C7',
#        '24-DF-6A-84-03-22', '24-DF-6A-C6-F3-79', '28-E3-1F-C8-36-A3',
#        '2C-5B-B8-8E-8B-32', '30-10-B3-BA-D0-F4', '34-80-B3-88-58-09',
#        '38-A4-ED-05-1B-F3', '38-BC-1A-C6-DF-BA', '38-BC-1A-D1-97-C8',
#        '38-BC-1A-D8-A7-36', '40-16-9F-83-9F-F9', '40-33-1A-F1-EE-E8',
#        '40-C6-2A-22-CA-42', '40-C6-2A-87-74-18', '44-33-4C-3A-6A-67',
#        '48-6B-2C-63-8F-0C', '50-9E-A7-66-5A-C0', '58-44-98-11-CC-04',
#        '58-44-98-13-50-AE', '60-D9-A0-9A-95-0C', '64-09-80-F5-05-A2',
#        '68-07-15-3F-28-ED', '68-3E-34-0D-51-1E', '68-3E-34-14-3E-AF',
# ...

# %%
ff = pd.DataFrame(fs,columns=['Target_Priority','100','101','102','103','104','105'])
ff
# Out:
#                    Target_Priority  100  101  102  103  104  105
# Target_Priority
# 00-08-CA-6D-17-DA              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 00-19-E0-87-5A-87              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 00-9A-CD-78-02-1B              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 00-BB-3A-C5-E5-63              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 04-02-1F-29-1B-F3              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 08-EE-8B-DF-4E-EB              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10-2A-B3-4A-96-83              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10-2A-B3-E5-EC-7D              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14-F6-5A-AD-02-2D              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 18-DC-56-D0-31-39              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1C-3E-84-0F-A2-17              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1C-67-58-EA-B8-28              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20-82-C0-74-C1-B7              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...
