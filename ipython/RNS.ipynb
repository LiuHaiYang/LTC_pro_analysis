# %%
# %matplotlib inline
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
result = pd.read_csv('ltc_v1.0_Data_7_25_5.csv',sep=',')
result.head()
# Out:
#    id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt   BW   CR  \
# 0   1                    39  LTC-base1    1    2    2    8      -86  125  4/5
# 1   2                    39  LTC-base1    1    2    4    8      -84  125  4/5
# 2   3                    39  LTC-base1    1    2    7    8      -90  125  4/5
# 3   4                    39  LTC-base1    1    2    0    8      -91  125  4/5
# 4   5                    39  LTC-base1    1    2    1    7      -88  125  4/5
#
#    SF  sensor_id  version  command_id  data_length data  mote_lon  mote_lat  \
# 0  12          2        1           9            1    ,       0.0       0.0
# 1  12          2        1           9            1    ,       0.0       0.0
# 2  12          2        1           9            1    ,       0.0       0.0
# 3  12          2        1           9            1    ,       0.0       0.0
# 4  12          2        1           9            1    ,       0.0       0.0
#
#              time  distance2base
# ...

# %%
address6_1=result[result['id']>327]
address6=address6_1[address6_1['id']<410]
address6.count()
# Out:
# id                      82
# collcetion_latest_id    82
# base_topic              82
# dst                     82
# src                     82
# seq                     82
# SNR                     82
# RSSIpkt                 82
# BW                      82
# CR                      82
# SF                      82
# sensor_id               82
# version                 82
# command_id              82
# data_length             82
# data                    82
# mote_lon                82
# mote_lat                82
# time                    82
# distance2base           82
# dtype: int64

# %%
y=address6['id']
plt.bar(height =address6['SNR'],left=y)
# Out:
# <Container object of 82 artists>

# %%
plt.scatter(address6['id'],address6['SNR'],c='r')

# %%
address6_4=address6[address6['src']==4]
address6_4
# Out:
#       id  collcetion_latest_id base_topic  dst  src  seq  SNR  RSSIpkt   BW  \
# 380  381                    37  LTC-base1    1    4    0    8      -90  125
# 381  382                    37  LTC-base1    1    4    1    8      -93  125
# 382  383                    37  LTC-base1    1    4    2    7      -96  125
# 383  384                    37  LTC-base1    1    4    3    6     -109  125
# 384  385                    37  LTC-base1    1    4    4    8      -92  125
# 385  386                    37  LTC-base1    1    4    5    9      -88  125
# 386  387                    37  LTC-base1    1    4    6   10      -87  125
# 387  388                    37  LTC-base1    1    4    7    9      -87  125
# 388  389                    37  LTC-base1    1    4    8    9      -87  125
# 389  390                    37  LTC-base1    1    4    9    9      -88  125
# 390  391                    37  LTC-base1    1    4    0   10      -89  125
# ...

# %%
plt.scatter(address6_4['id'],address6_4['SNR'],c='r')

# %%
fig_3 = plt.figure()

ax = fig_3.add_subplot(2,2,1)
ax = fig_3.add_subplot(2,2,2)
ax = fig_3.add_subplot(2,2,3)
