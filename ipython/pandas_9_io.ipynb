# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.read_csv('D:\\pandas\\pandas_work\\数据\\data\\data.csv')
# Out:
#     Unnamed: 0         A         B         C         D
# 0            0  0.339239  0.100224  0.335220  0.072110
# 1            1  0.464054  0.932793  0.749538  0.016782
# 2            2  0.463768  0.051170  0.047155  0.055797
# 3            3  0.088635  0.107325  0.271865  0.487323
# 4            4  0.479307  0.890176  0.560822  0.879968
# 5            5  0.570288  0.699495  0.674113  0.954930
# 6            6  0.159397  0.265766  0.078858  0.811305
# 7            7  0.280346  0.880105  0.973268  0.091684
# 8            8  0.007739  0.142329  0.868540  0.357108
# 9            9  0.738756  0.395562  0.462939  0.882009
# 10          10  0.396642  0.522881  0.014462  0.150421
# 11          11  0.037312  0.301376  0.515950  0.112682
# 12          12  0.090370  0.275222  0.613837  0.333395
# 13          13  0.001228  0.214112  0.851570  0.461011
# 14          14  0.121506  0.743186  0.469344  0.259502
# 15          15  0.063427  0.364651  0.921653  0.876740
# ...

# %%
# %more data.csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-bf743eeb4b80> in <module>()
# ----> 1 get_ipython().magic('more data.csv')
#
# f:\python\python3.5\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# f:\python\python3.5\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
# ...

# %%
df = pd.read_table('D:\\pandas\\pandas_work\\数据\\data\\data.csv',sep=',')

# %%
pd.read_csv('D:\\pandas\\pandas_work\\数据\\data\\data.csv',header=None)
# Out:
#         0                      1                     2                     3  \
# 0     NaN                      A                     B                     C
# 1     0.0     0.3392392411146423   0.10022392847464567   0.33521960088328484
# 2     1.0    0.46405408558401184    0.9327927216341503    0.7495376255541872
# 3     2.0    0.46376837304094654  0.051170009652158344   0.04715521190584482
# 4     3.0    0.08863463626095403   0.10732519948039321   0.27186478097876265
# 5     4.0     0.4793072355993594    0.8901763695907065    0.5608215048216696
# 6     5.0     0.5702878346719464    0.6994951548715512    0.6741133764384246
# 7     6.0    0.15939686385919405     0.265765904703123   0.07885768236540525
# 8     7.0     0.2803459291077781    0.8801054003493763    0.9732678767553882
# 9     8.0  0.0077390184151432395   0.14232864551259616    0.8685401224369389
# 10    9.0     0.7387564540593755   0.39556166845948726    0.4629392118595653
# ...

# %%
df.to_csv('data_out.csv')

# %%
df.to_csv('data_out_o.csv', index=False)

# %%
df.to_csv('data_out_o1.csv', index=False,header=None)
