# %%
#导入python库
# %matplotlib inline
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import MySQLdb
import re

# %%
#读取数据
pd.read_csv()
pd.read_table()
pd.read_excel()
pd.read_json()

# %%
con = MySQLdb.connect(host='127.0.0.1',user='root',passwd='843800695',db='python_test',charset='utf8')
sql = "select * from test"
index = ['id','door_name','user_name','user_id','door_open']
data = pd.read_sql(sql,con,columns=index)
data
# Out:
#         id                date door_name user_name user_type door_open  \
# 0      178 2016-10-21 21:18:00   119教室北门       李伟豪        学生         真
# 1      179 2016-10-21 21:16:00   118教室北门       刘海洋        学生         真
# 2      180 2016-10-21 21:00:00   116教室南门        薛衎        学生         真
# 3      181 2016-10-21 20:53:00   119教室北门       许振林        学生         真
# 4      182 2016-10-21 20:52:00   117教室南门       唐治涛        学生         真
# 5      183 2016-10-21 20:10:00   116教室北门       张会敏        学生         真
# 6      184 2016-10-21 20:09:00   118教室北门        娄尚        学生         真
# 7      185 2016-10-21 20:05:00   116教室南门        薛衎        学生         真
# 8      186 2016-10-21 20:04:00   116教室北门        甄重        学生         真
# 9      187 2016-10-21 19:59:00   117教室南门        甄重        学生         真
# 10     188 2016-10-21 19:32:00   116教室南门       刘晓东        学生         真
# 11     189 2016-10-21 18:49:00   116教室南门       刘晓东        学生         真
# ...

# %%
#显示重复值
data['user_type'].duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16     False
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 812     True
# 813     True
# 814     True
# 815     True
# 816     True
# 817     True
# 818     True
# 819     True
# 820     True
# 821     True
# 822     True
# 823     True
# 824     True
# 825     True
# 826     True
# 827     True
# 828     True
# 829     True
# 830     True
# 831     True
# 832     True
# 833     True
# 834     True
# 835     True
# 836     True
# 837     True
# 838     True
# 839     True
# 840     True
# 841    False
# Name: user_type, dtype: bool

# %%
#删除重复值
data[''].drop_duplicates()
# Out:
#         id                date door_name user_name user_type door_open  \
# 0      178 2016-10-21 21:18:00   119教室北门       李伟豪        学生         真
# 1      179 2016-10-21 21:16:00   118教室北门       刘海洋        学生         真
# 2      180 2016-10-21 21:00:00   116教室南门        薛衎        学生         真
# 3      181 2016-10-21 20:53:00   119教室北门       许振林        学生         真
# 4      182 2016-10-21 20:52:00   117教室南门       唐治涛        学生         真
# 5      183 2016-10-21 20:10:00   116教室北门       张会敏        学生         真
# 6      184 2016-10-21 20:09:00   118教室北门        娄尚        学生         真
# 7      185 2016-10-21 20:05:00   116教室南门        薛衎        学生         真
# 8      186 2016-10-21 20:04:00   116教室北门        甄重        学生         真
# 9      187 2016-10-21 19:59:00   117教室南门        甄重        学生         真
# 10     188 2016-10-21 19:32:00   116教室南门       刘晓东        学生         真
# 11     189 2016-10-21 18:49:00   116教室南门       刘晓东        学生         真
# ...

# %%
#判断某一列是否有空值，isnull()
data['user_type'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 812    False
# 813    False
# 814    False
# 815    False
# 816    False
# 817    False
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# 823    False
# 824    False
# 825    False
# 826    False
# 827    False
# 828    False
# 829    False
# 830    False
# 831    False
# 832    False
# 833    False
# 834    False
# 835    False
# 836    False
# 837    False
# 838    False
# 839    False
# 840    False
# 841     True
# Name: user_type, dtype: bool

# %%
#判断某一列空值个数，
data['user_type'].isnull().value_counts()
# Out:
# False    841
# True       1
# Name: user_type, dtype: int64

# %%
#notnull() 
data['user_type'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 812     True
# 813     True
# 814     True
# 815     True
# 816     True
# 817     True
# 818     True
# 819     True
# 820     True
# 821     True
# 822     True
# 823     True
# 824     True
# 825     True
# 826     True
# 827     True
# 828     True
# 829     True
# 830     True
# 831     True
# 832     True
# 833     True
# 834     True
# 835     True
# 836     True
# 837     True
# 838     True
# 839     True
# 840     True
# 841    False
# Name: user_type, dtype: bool

# %%
#对某列空值内容进行填充
data_1 = data['user_type'].fillna(0)

# %%
#解决字段中存在的空格
data['']=data[''].value_counts()
#出去空格的三种方法
# data['']=loandata['term'].map(str.strip)
# data['']=loandata['term'].map(str.lstrip)
# data['']=loandata['term'].map(str.rstrip)
# Out:
# 0      学生
# 1      学生
# 2      学生
# 3      学生
# 4      学生
# 5      学生
# 6      学生
# 7      学生
# 8      学生
# 9      学生
# 10     学生
# 11     学生
# 12     学生
# 13     学生
# 14     学生
# 15     学生
# 16     老师
# 17     老师
# 18     学生
# 19     学生
# 20     学生
# 21     学生
# 22     学生
# 23     学生
# 24     老师
# 25     学生
# 26     学生
# 27     学生
# 28     学生
# 29     学生
#        ..
# 812    学生
# 813    学生
# 814    学生
# 815    学生
# 816    老师
# 817    学生
# 818    学生
# 819    未知
# 820    学生
# 821    学生
# 822    学生
# 823    学生
# 824    老师
# 825    学生
# 826    学生
# 827    学生
# 828    学生
# 829    学生
# 830    学生
# 831    学生
# 832    学生
# 833    学生
# 834    学生
# 835    学生
# 836    老师
# 837    学生
# 838    学生
# 839    学生
# 840    学生
# 841     0
# Name: user_type, dtype: object

# %%
#大小写转换：全部转换为大写，全部转换为小写，和转换为首字母大写。
# data['user_name']=data['user_name'].map(str.upper)
data['user_name']=data['user_name'].map(str.lower)
# data['']=data[''].map(str.title)
data

# %%
data.dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# door_name              object
# user_name              object
# user_type              object
# door_open              object
# user_id               float64
# door_adress            object
# car_id                 object
# dtype: object

# %%
#更改数据格式
data['id']=data['id'].astype(np.float64)
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-70bca2cfca29> in <module>()
#       1 #更改数据格式
# ----> 2 data['door_adress']=data['door_adress'].astype(np.int64)
#       3 data.dtypes
#
# C:\Users\samsung1\AppData\Roaming\Python\Python35\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    3052         # else, only a single dtype is given
#    3053         new_data = self._data.astype(dtype=dtype, copy=copy,
# -> 3054                                      raise_on_error=raise_on_error, **kwargs)
#    3055         return self._constructor(new_data).__finalize__(self)
#    3056
#
# C:\Users\samsung1\AppData\Roaming\Python\Python35\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3166
#    3167     def astype(self, dtype, **kwargs):
# ...

# %%
data['id']=data['id'].astype(np.int64)
data.dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# door_name              object
# user_name              object
# user_type              object
# door_open              object
# user_id               float64
# door_adress            object
# car_id                 object
# dtype: object

# %%
#数据中的异常和极端值，要关注最大值(max)和最小值(min)情况。
data.describe().astype(np.int64).T
# Out:
#          count       mean       std    min        25%        50%        75%  \
# id         842       2559      1066    178       2571       2781       3191
# user_id    792  123407114  43282065  12232  130310235  140210312  140710223
#
#                max
# id           10005
# user_id  160210426

# %%
#替换 
data.replace([100000,10],loandata[''].mean())

# %%
data_a = data

# %%
#数据分组
bins = [0, 500, 1000, 1500, 4000]
group_names = ['A-b', 'B-c', 'C-d', 'D-e']
data_a['categories'] = pd.cut(data_a['id'], bins, labels=group_names)
data_a
# Out:
#         id                date door_name user_name user_type door_open  \
# 0      178 2016-10-21 21:18:00   119教室北门       李伟豪        学生         真
# 1      179 2016-10-21 21:16:00   118教室北门       刘海洋        学生         真
# 2      180 2016-10-21 21:00:00   116教室南门        薛衎        学生         真
# 3      181 2016-10-21 20:53:00   119教室北门       许振林        学生         真
# 4      182 2016-10-21 20:52:00   117教室南门       唐治涛        学生         真
# 5      183 2016-10-21 20:10:00   116教室北门       张会敏        学生         真
# 6      184 2016-10-21 20:09:00   118教室北门        娄尚        学生         真
# 7      185 2016-10-21 20:05:00   116教室南门        薛衎        学生         真
# 8      186 2016-10-21 20:04:00   116教室北门        甄重        学生         真
# 9      187 2016-10-21 19:59:00   117教室南门        甄重        学生         真
# 10     188 2016-10-21 19:32:00   116教室南门       刘晓东        学生         真
# 11     189 2016-10-21 18:49:00   116教室南门       刘晓东        学生         真
# ...

# %%
data_a.dtypes
data_a['categories']=data_a['categories'].astype(str)
data_a.dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# door_name              object
# user_name              object
# user_type              object
# door_open              object
# user_id               float64
# door_adress            object
# car_id                 object
# categories             object
# dtype: object

# %%
#数据分列
data_b= pd.DataFrame((x.split('-') for x in data_a.categories),index=data.index,columns=['grade','sub_grade'])
data_b
# Out:
#     grade sub_grade
# 0       A         b
# 1       A         b
# 2       A         b
# 3       A         b
# 4       A         b
# 5       A         b
# 6       A         b
# 7       A         b
# 8       A         b
# 9       A         b
# 10      A         b
# 11      A         b
# 12      A         b
# 13      A         b
# 14      A         b
# 15      A         b
# 16      A         b
# 17      A         b
# 18      A         b
# 19      A         b
# 20      A         b
# 21      A         b
# 22      A         b
# 23      A         b
# 24      A         b
# 25      A         b
# 26      A         b
# 27      A         b
# 28      A         b
# 29      A         b
# ..    ...       ...
# 812     D         e
# 813     D         e
# 814     D         e
# 815     D         e
# 816     D         e
# 817     D         e
# 818     D         e
# 819     D         e
# 820     D         e
# 821     D         e
# 822     D         e
# 823     D         e
# 824     D         e
# ...

# %%
#合并
data_f = pd.merge(data_a,data_b,right_index=True,left_index=True)
data_f
# Out:
#         id                date door_name user_name user_type door_open  \
# 0      178 2016-10-21 21:18:00   119教室北门       李伟豪        学生         真
# 1      179 2016-10-21 21:16:00   118教室北门       刘海洋        学生         真
# 2      180 2016-10-21 21:00:00   116教室南门        薛衎        学生         真
# 3      181 2016-10-21 20:53:00   119教室北门       许振林        学生         真
# 4      182 2016-10-21 20:52:00   117教室南门       唐治涛        学生         真
# 5      183 2016-10-21 20:10:00   116教室北门       张会敏        学生         真
# 6      184 2016-10-21 20:09:00   118教室北门        娄尚        学生         真
# 7      185 2016-10-21 20:05:00   116教室南门        薛衎        学生         真
# 8      186 2016-10-21 20:04:00   116教室北门        甄重        学生         真
# 9      187 2016-10-21 19:59:00   117教室南门        甄重        学生         真
# 10     188 2016-10-21 19:32:00   116教室南门       刘晓东        学生         真
# 11     189 2016-10-21 18:49:00   116教室南门       刘晓东        学生         真
# ...

# %%
#保存数据 csv  json  
data_f = pd.to_csv('/data.csv')
