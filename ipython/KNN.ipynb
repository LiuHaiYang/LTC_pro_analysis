# %%
# %matplotlib inline
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=12)
fontt=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=16)

# %%
data= pd.read_csv('data1.csv',index_col='Target_ID')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c1b7ebebdb27> in <module>()
# ----> 1 data= pd.read_csv('data1.csv',index_col='Target_ID')
#
# ...

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-199065406915> in <module>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
virginica=data.ix['Iris-virginica']
setosa=data.ix['Iris-setosa']
versicolor=data.ix['Iris-versicolor']

# %%
plt.scatter(setosa['hbl'],setosa['hbk'],label='setosa',c='r')
plt.scatter(versicolor['hbl'],versicolor['hbk'],label='versicolor',c='y')
plt.scatter(virginica['hbl'],virginica['hbk'],label='virginica',c='g')
plt.legend()
plt.title(u'花瓣',fontproperties=fontt)
plt.figtext(0.4,-0.01,'花瓣长度',fontproperties=font)
plt.figtext(-0.02,0.5,u'花瓣宽度',fontproperties=font)

# %%
plt.scatter(setosa['epl'],setosa['epk'],label='setosa',c='r')
plt.scatter(versicolor['epl'],versicolor['epk'],label='versicolor',c='y')
plt.scatter(virginica['epl'],virginica['epk'],label='virginica',c='g')
plt.legend(loc=2)
plt.title(u'萼片',fontproperties=fontt)
plt.figtext(0.5,-0.02,u'萼片长度',fontproperties=font)
plt.figtext(-0.01,0.5,u'萼片宽度',fontproperties=font)

# %%
plt.scatter(data['Target_Access_DT'],data['Pin_ID'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2673a4e9d40b> in <module>()
# ----> 1 plt.scatter(data['Target_Access_DT'],data['Pin_ID'])
#
# C:\Users\samsung1\AppData\Roaming\Python\Python35\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3256                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3257                          linewidths=linewidths, verts=verts,
# -> 3258                          edgecolors=edgecolors, data=data, **kwargs)
#    3259     finally:
#    3260         ax.hold(washold)
#
# C:\Users\samsung1\AppData\Roaming\Python\Python35\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
# ...
