# %%
# %matplotlib inline
import pandas as pd
import image
from numpy.random import randn

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import time

# %%
img = plt.imread('G:\\个人资料\\图库\\桌面\\1111.png')

# %%
plt.imshow(img)

# %%
# %logstart
# Out:
# f:\python\python3.5\lib\site-packages\IPython\core\magics\logging.py:120: UserWarning: Couldn't start log: Log file is already active: ipython_log.py
#   warn("Couldn't start log: %s" % sys.exc_info()[1])

# %%
2**27
# Out:
# 134217728

# %%
# %dhist
# Out:
# Directory history (kept in _dh)
# 0: D:\pandas\pandas_work\ipython

# %%
x = 'foobar'
y = 'foo'

# %%
# %timeit x.startswith(y)
# Out:
# The slowest run took 12.69 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 679 ns per loop

# %%
# %timeit x[:3] ==y
# Out:
# The slowest run took 6.66 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 555 ns per loop
